# %% [markdown]
# # RCFM Model

# %% [markdown]
# ## 1. Import modules and helper functions

# %%
# Modules
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt
from scipy.optimize import curve_fit

# Helper functions from DataAid.py and DataImport.py
import DataAid
import DataImporter

# Numerically stable class of functions from Neros_v2.py
import Neros_test

# %% [markdown]
# ## 2. Load Galaxy Data

# %%
# Load Galaxy Data
sparcGalaxies = DataAid.GetGalaxyData("data/Sparc/Rotmod_LTG/")
sparc128Galaxies = DataAid.GetGalaxyData("data/Sparc/SparcSubset135/")
sparcTset = DataAid.GetGalaxyData("data/Sparc/TrainingSet/")
littleDataGalaxies = DataAid.GetGalaxyData("data/little-data-things/data/")
lcmGalaxies = DataAid.GetGalaxyData("data/LCMFits/data/")

# Load Milky Way Model Data
xueSofueGalaxies = DataAid.GetGalaxyData("data/XueSofue/")
mcGaughMW = DataAid.GetGalaxyData("data/McGaugh/")

# Create array of Milky Way radius and vlum tuples from model data
MWXueSofue = np.array(xueSofueGalaxies['MW_lum'])
MWMcGaugh = np.array(mcGaughMW['MW_lumMcGaugh'])

# %% [markdown]
# ## 3. Create Neros class instance

# %%
# Create Neros instance to perform calculations with the supplied Milky Way model as comparison
# Change Milky Way model by changing the variable in the parentheses
# i.e. neros_fns = Neros_v2.Neros(MWModelVariable)

neros_fns = Neros_test.Neros(MWXueSofue)
MW_name = "XueSofue" # Change this if you change the MW model in neros_fns!
MW_rad = neros_fns.mw_rad
MW_vLum = neros_fns.mw_vLum
#MW_phi = neros_fns.mw_phi

MW_vLum_interp_func = neros_fns.mw_vLum_interp

# %% [markdown]
# ## 4. Designate outfile name, initialize variables, and designate galaxy sample

# %%
# This designates which galaxy sample to fit
galaxies = sparcTset

# %% [markdown]
# ## 5. Fit galaxies, print and save graphs

# %%
"""
This is the main body of the model. 
It loops through galaxies in the designated sample,
it calculates vLCM, vNeros, and chiSquared,
it fits galaxy data using alpha and vLumFreeParam,
it prints the values of alpha and vLumFreeParam to the console,
and it saves the graphs to a file.
"""

# This is where the fitted alpha & vlum free parameter will be written for each galaxy
out_file = "imported-data/data_" + str(MW_name) + ".csv"
with open(out_file, 'w') as f:
    f.write('{0},{1},{2},{3},{4},{5}\n'.format("Galaxy", "chi_square",  "alpha", "disk_scale", "bulge_scale","phi_zero"))
f.close()

total_chi_squared = []


for galaxyName in galaxies:
    f, ax = plt.subplots(1, figsize = (15, 15))
    
    # Extract out the needed galaxy components
    galaxy = np.array(galaxies[galaxyName])
    galaxy_rad = galaxy[:,0]
    galaxy_vObs = galaxy[:,1]
    galaxy_error = galaxy[:,2]
    galaxy_gas = galaxy[:,3]
    galaxy_disk = galaxy[:,4]
    galaxy_bulge = galaxy[:,5]

    # Just fit then extract the relevant pieces
    neros_fns.fit(galaxy_rad, galaxy_gas, galaxy_disk, galaxy_bulge, galaxy_vObs, galaxy_error)

    print(f"galaxyName is: {galaxyName}")
    fit_results = neros_fns.get_fit_results(galaxy_rad)
    for param in fit_results:
        print(f"{param} is: {fit_results[param]}")
    print("--------------------------")
    
    total_chi_squared.append(fit_results['chi_squared'])
    
    print("Running average chi_squared: {}".format(sum(total_chi_squared)/len(total_chi_squared)))

    
    # Write galaxyName, fitted parameters
    with open(out_file, 'a') as f:
        f.write(f"{galaxyName},{fit_results['chi_squared']},{fit_results['alpha']}, \
                {fit_results['disk_scale']},{fit_results['bulge_scale']},{fit_results['phi_zero']} \n")
    f.close()

    trimmed_rad = neros_fns.get_rad()
    trimmed_vLum_updated = neros_fns.get_vLum_scaled()
    trimmed_vObs = neros_fns.get_vObs()
    trimmed_error = neros_fns.get_vObsError()
    vNeros = neros_fns.get_vNeros()
    
    # plot
    # y-axis scales to the maximum velocity value in the list galaxy_vObs_err_incl
    # or to the maximum value in the list vNeros, whichever is the bigger number
    y_max = max(max(trimmed_vObs + trimmed_error), max(vNeros))
    ax.set_ylim(bottom = 0, top = y_max + 15)

    # plot vObs and vNeros and updated vLum
    ax.plot(trimmed_rad, vNeros, label="{}_vNeros".format(galaxyName))
    ax.plot(trimmed_rad, trimmed_vObs, label="{}_vObs".format(galaxyName))
    ax.plot(trimmed_rad, trimmed_vLum_updated, label="{}_new_vLum".format(galaxyName))
    ax.plot([],[], ' ', label="$\chi^2$ = {}".format(fit_results['chi_squared']))

    # error bar in vObs
    for i in range(len(trimmed_rad)):
        ax.vlines(trimmed_rad[i], trimmed_vObs[i] - trimmed_error[i], trimmed_vObs[i] + trimmed_error[i])

    ax.legend(loc="upper right")

    graph_file_name = "graph/" + str(galaxyName) + "_" + str(MW_name)

    plt.savefig(graph_file_name)
# Out:
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGCA442_rotmod
# chi_squared is: 0.5034200333536664
# alpha is: 0.0006897746119152193
# disk_scale is: 2.2357131154263987
# bulge_scale is: 1.0
# phi_zero is: 2.8647946796093216e-06
# --------------------------
# Running average chi_squared: 0.5034200333536664
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGC04305_rotmod
# chi_squared is: 1.552163812928533
# alpha is: 1.7854175426860506e-14
# disk_scale is: 0.8755215319984063
# bulge_scale is: 1.0
# phi_zero is: 3.618760298237866e-06
# --------------------------
# Running average chi_squared: 1.0277919231410997
# galaxyName is: NGC2841_rotmod
# chi_squared is: 1.2486149717628272
# alpha is: 2.471599311363228e-06
# disk_scale is: 0.9465944977681099
# bulge_scale is: 1.0957022026506602
# phi_zero is: 3.985111620249881e-06
# --------------------------
# Running average chi_squared: 1.1013996060150089
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGC07232_rotmod
# chi_squared is: 0.21873633484652777
# alpha is: 0.003840369376006398
# disk_scale is: 0.785402642490305
# bulge_scale is: 1.0
# phi_zero is: 2.3682255868199998e-06
# --------------------------
# Running average chi_squared: 0.8807337882228886
# galaxyName is: NGC4068_rotmod
# chi_squared is: 0.129187633074088
# alpha is: 0.003445327994746343
# disk_scale is: 0.781754810104562
# bulge_scale is: 1.0
# phi_zero is: 2.6562252603554394e-06
# --------------------------
# Running average chi_squared: 0.7304245571931285
# galaxyName is: D564-8_rotmod
# chi_squared is: 0.038569978425180854
# alpha is: 0.011089409944100266
# disk_scale is: 1.1661261694168077
# bulge_scale is: 1.0
# phi_zero is: 2.6562252603554394e-06
# --------------------------
# Running average chi_squared: 0.6151154607318039
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC0024_rotmod
# chi_squared is: 0.6820997352171764
# alpha is: 2.4846439198996035e-05
# disk_scale is: 1.381191489466
# bulge_scale is: 1.0
# phi_zero is: 3.743967144766226e-06
# --------------------------
# Running average chi_squared: 0.6246846428011429
# galaxyName is: DDO168_rotmod
# chi_squared is: 2.973705416056844
# alpha is: 0.0038518572697990652
# disk_scale is: 0.6010981012969966
# bulge_scale is: 1.0
# phi_zero is: 3.065057007881928e-06
# --------------------------
# Running average chi_squared: 0.9183122394581055
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: D631-7_rotmod
# chi_squared is: 0.2554109841914732
# alpha is: 0.007515129637562087
# disk_scale is: 0.12155826520037724
# bulge_scale is: 1.0
# phi_zero is: 3.392034252601659e-06
# --------------------------
# Running average chi_squared: 0.8446565444284797
# galaxyName is: UGC01281_rotmod-Copy1
# chi_squared is: 0.2948562173337389
# alpha is: 0.0015314834382333545
# disk_scale is: 1.3942247866853683
# bulge_scale is: 1.0
# phi_zero is: 3.681322409857878e-06
# --------------------------
# Running average chi_squared: 0.7896765117190057
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC2976_rotmod
# chi_squared is: 0.4084347079519343
# alpha is: 9.645843568563325e-05
# disk_scale is: 0.9040978032317978
# bulge_scale is: 1.0
# phi_zero is: 3.7125273763091643e-06
# --------------------------
# Running average chi_squared: 0.7550181659219991
# galaxyName is: NGC6946_rotmod
# chi_squared is: 1.686479268056768
# alpha is: 6.240148434957662e-06
# disk_scale is: 0.6435025890462001
# bulge_scale is: 0.5542195684402975
# phi_zero is: 4.032308821953264e-06
# --------------------------
# Running average chi_squared: 0.8326399244332299
# galaxyName is: NGC7331_rotmod
# chi_squared is: 0.9170679370498925
# alpha is: 5.232477477080738e-06
# disk_scale is: 0.5374269027036679
# bulge_scale is: 1.1235686113945522
# phi_zero is: 3.877713734514092e-06
# --------------------------
# Running average chi_squared: 0.839134386942204
# galaxyName is: NGC5907_rotmod
# chi_squared is: 6.431399430248307
# alpha is: 5.024920603214671e-06
# disk_scale is: 0.9423535870962705
# bulge_scale is: 1.0
# phi_zero is: 3.4926067951406126e-06
# --------------------------
# Running average chi_squared: 1.2385818900354972
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC3198_rotmod
# chi_squared is: 1.6269684899421057
# alpha is: 2.1277222695602606e-05
# disk_scale is: 0.8727337724640943
# bulge_scale is: 1.0
# phi_zero is: 3.935691023684328e-06
# --------------------------
# Running average chi_squared: 1.264474330029271
# galaxyName is: NGC0891_rotmod
# chi_squared is: 2.889681006098714
# alpha is: 6.634457403735033e-06
# disk_scale is: 0.4054563877929534
# bulge_scale is: 0.7443058447444344
# phi_zero is: 3.4685488224002466e-06
# --------------------------
# Running average chi_squared: 1.3660497472836113
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC3741_rotmod
# chi_squared is: 0.5689472637503872
# alpha is: 0.019287623258875203
# disk_scale is: 0.6527945578091132
# bulge_scale is: 1.0
# phi_zero is: 3.558005140268911e-06
# --------------------------
# Running average chi_squared: 1.319161365899304
# galaxyName is: NGC0247_rotmod
# chi_squared is: 1.9424379568311225
# alpha is: 2.0189309670112587e-05
# disk_scale is: 1.5245743876879778
# bulge_scale is: 1.0
# phi_zero is: 3.694658858819989e-06
# --------------------------
# Running average chi_squared: 1.353787843173294
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /var/folders/hr/rgx9wwtn6_d2_zk18m_d1skw0000gn/T/ipykernel_22288/3349071353.py:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f, ax = plt.subplots(1, figsize = (15, 15))
# galaxyName is: UGC07524_rotmod
# chi_squared is: 1.317191252985464
# alpha is: 9.23772020254932e-05
# disk_scale is: 1.5697067067387391
# bulge_scale is: 1.0
# phi_zero is: 3.7727107017916375e-06
# --------------------------
# Running average chi_squared: 1.3518617068476186
# galaxyName is: UGC07151_rotmod
# chi_squared is: 0.9116883977135299
# alpha is: 8.148831897634947e-05
# disk_scale is: 1.1444380237287335
# bulge_scale is: 1.0
# phi_zero is: 3.1310131610425587e-06
# --------------------------
# Running average chi_squared: 1.3298530413909142
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGC04483_rotmod
# chi_squared is: 0.2876817507395805
# alpha is: 0.0025226168113152685
# disk_scale is: 1.2237158014654073
# bulge_scale is: 1.0
# phi_zero is: 2.8647946796093216e-06
# --------------------------
# Running average chi_squared: 1.280225837074184
# galaxyName is: NGC0055_rotmod
# chi_squared is: 2.29621400055765
# alpha is: 0.00028513785330977557
# disk_scale is: 0.9954019514894468
# bulge_scale is: 1.0
# phi_zero is: 3.558005140268911e-06
# --------------------------
# Running average chi_squared: 1.3264071172325234
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC2403_rotmod
# chi_squared is: 10.35448424068854
# alpha is: 5.124667151556765e-05
# disk_scale is: 0.8478584845288942
# bulge_scale is: 1.0
# phi_zero is: 4.103703637097236e-06
# --------------------------
# Running average chi_squared: 1.718932209556698
# galaxyName is: ESO444-G084_rotmod
# chi_squared is: 0.33325817143270614
# alpha is: 0.001270998737288514
# disk_scale is: 1.7785403986491908
# bulge_scale is: 1.0
# phi_zero is: 2.7697701267296215e-06
# --------------------------
# Running average chi_squared: 1.6611957913015314
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC6789_rotmod
# chi_squared is: 0.17241057748496438
# alpha is: 0.002070795742329515
# disk_scale is: 1.3527545883853265
# bulge_scale is: 1.0
# phi_zero is: 2.3682255868199998e-06
# --------------------------
# Running average chi_squared: 1.6016443827488689
# galaxyName is: UGC08490_rotmod
# chi_squared is: 0.12352108654776198
# alpha is: 0.00011077801643683318
# disk_scale is: 1.233156914510559
# bulge_scale is: 1.0
# phi_zero is: 3.7576123992122394e-06
# --------------------------
# Running average chi_squared: 1.544793486741134
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGC07559_rotmod
# chi_squared is: 0.11222804842093659
# alpha is: 0.0026731528136237207
# disk_scale is: 0.9513925465969802
# bulge_scale is: 1.0
# phi_zero is: 2.7697701267296215e-06
# --------------------------
# Running average chi_squared: 1.4917355075440897
# galaxyName is: NGC2915_rotmod
# chi_squared is: 0.5561112138009178
# alpha is: 0.002862171783371028
# disk_scale is: 0.5079529836538702
# bulge_scale is: 1.0
# phi_zero is: 3.7576123992122394e-06
# --------------------------
# Running average chi_squared: 1.4583203541961194
# galaxyName is: NGC5055_rotmod
# chi_squared is: 5.965473373856845
# alpha is: 4.755372284768578e-06
# disk_scale is: 0.6221256024740476
# bulge_scale is: 1.0
# phi_zero is: 3.729889199668195e-06
# --------------------------
# Running average chi_squared: 1.6137394238395926
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC6503_rotmod
# chi_squared is: 1.1882452530689518
# alpha is: 4.564624131253579e-05
# disk_scale is: 0.7324689993134083
# bulge_scale is: 1.0
# phi_zero is: 3.7727107017916375e-06
# --------------------------
# Running average chi_squared: 1.5995562848139044
# galaxyName is: PGC51017_rotmod
# chi_squared is: 1.1562586021376158
# alpha is: 8.069879316772003e-14
# disk_scale is: 0.8004541047313517
# bulge_scale is: 1.0
# phi_zero is: 2.6562252603554394e-06
# --------------------------
# Running average chi_squared: 1.5852563595662823
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC1705_rotmod
# chi_squared is: 0.13526283639460604
# alpha is: 0.00010095485497326174
# disk_scale is: 1.1986390467030024
# bulge_scale is: 1.0
# phi_zero is: 3.3099192613718044e-06
# --------------------------
# Running average chi_squared: 1.5399440619671676
# galaxyName is: UGC07577_rotmod
# chi_squared is: 0.038178134874364125
# alpha is: 0.011158392801456318
# disk_scale is: 0.6585274278052375
# bulge_scale is: 1.0
# phi_zero is: 2.9716371906492047e-06
# --------------------------
# Running average chi_squared: 1.494436003570416
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC0300_rotmod
# chi_squared is: 0.3691804906352479
# alpha is: 0.00022921716702847762
# disk_scale is: 1.1246477995268698
# bulge_scale is: 1.0
# phi_zero is: 3.681322409857878e-06
# --------------------------
# Running average chi_squared: 1.4613402531899697
# galaxyName is: NGC7793_rotmod
# chi_squared is: 0.6906309683265791
# alpha is: 3.286767000565014e-05
# disk_scale is: 0.8810478535141363
# bulge_scale is: 1.0
# phi_zero is: 3.958659388027099e-06
# --------------------------
# Running average chi_squared: 1.4393199879081586
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: NGC4214_rotmod
# chi_squared is: 1.0048181609043505
# alpha is: 0.00011409970037840156
# disk_scale is: 0.987489659437735
# bulge_scale is: 1.0
# phi_zero is: 3.3099192613718044e-06
# --------------------------
# Running average chi_squared: 1.4272504927136085
# galaxyName is: UGC08837_rotmod
# chi_squared is: 0.4170447383398037
# alpha is: 0.0036563302930276123
# disk_scale is: 0.7706299767037649
# bulge_scale is: 1.0
# phi_zero is: 2.8647946796093216e-06
# --------------------------
# Running average chi_squared: 1.3999476344872894
# galaxyName is: UGC07866_rotmod
# chi_squared is: 0.0423702875751862
# alpha is: 0.0008040424145596451
# disk_scale is: 1.2490586338877634
# bulge_scale is: 1.0
# phi_zero is: 2.7697701267296215e-06
# --------------------------
# Running average chi_squared: 1.3642219148317078
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGC08286_rotmod
# chi_squared is: 2.2450879971862876
# alpha is: 9.391628752580079e-05
# disk_scale is: 1.6473967636428812
# bulge_scale is: 1.0
# phi_zero is: 3.426909797106068e-06
# --------------------------
# Running average chi_squared: 1.3868082246356714
# galaxyName is: NGC2683_rotmod
# chi_squared is: 0.7357119262103974
# alpha is: 4.063914199925259e-06
# disk_scale is: 0.8852276749722664
# bulge_scale is: 0.4333579833569565
# phi_zero is: 3.1310131610425587e-06
# --------------------------
# Running average chi_squared: 1.3705308171750397
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: IC2574_rotmod
# chi_squared is: 1.9679913791945491
# alpha is: 0.0023167938335175715
# disk_scale is: 1.0920579213184618
# bulge_scale is: 1.0
# phi_zero is: 3.856421041674189e-06
# --------------------------
# Running average chi_squared: 1.3851030260047839
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: UGCA444_rotmod
# chi_squared is: 0.08874362234180976
# alpha is: 0.0010825412520662767
# disk_scale is: 3.696642396385941
# bulge_scale is: 1.0
# phi_zero is: 3.877713734514092e-06
# --------------------------
# Running average chi_squared: 1.3542373259175702
# galaxyName is: NGC3109_rotmod
# chi_squared is: 0.24224133371744752
# alpha is: 0.00171949990230713
# disk_scale is: 2.0199418015263166
# bulge_scale is: 1.0
# phi_zero is: 3.681322409857878e-06
# --------------------------
# Running average chi_squared: 1.3283769540059394
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# galaxyName is: DDO154_rotmod
# chi_squared is: 7.512163398542317
# alpha is: 0.004373191681614386
# disk_scale is: 1.1250637915928137
# bulge_scale is: 1.0
# phi_zero is: 3.1919951620190414e-06
# --------------------------
# Running average chi_squared: 1.4689175550181297
# galaxyName is: UGCA281_rotmod
# chi_squared is: 0.1556835000922672
# alpha is: 0.0007805617511243301
# disk_scale is: 1.2165101262132836
# bulge_scale is: 1.0
# phi_zero is: 2.7697701267296215e-06
# --------------------------
# Running average chi_squared: 1.4397345760197773
# galaxyName is: CamB_rotmod
# chi_squared is: 0.2063496447819812
# alpha is: 0.05554109004534428
# disk_scale is: 3.99075440866513e-06
# bulge_scale is: 1.0
# phi_zero is: 2.9716371906492047e-06
# --------------------------
# Running average chi_squared: 1.4129218601233033
# galaxyName is: NGC7814_rotmod
# chi_squared is: 0.6197474755075112
# alpha is: 3.903168346220939e-06
# disk_scale is: 0.3896731794486852
# bulge_scale is: 0.6592487289743614
# phi_zero is: 3.4685488224002466e-06
# --------------------------
# Running average chi_squared: 1.3960458093867971
# galaxyName is: NGC2366_rotmod
# chi_squared is: 1.94768537095533
# alpha is: 0.0011516549860634598
# disk_scale is: 1.0391463882610763
# bulge_scale is: 1.0
# phi_zero is: 3.694658858819989e-06
# --------------------------
# Running average chi_squared: 1.4075383002528081
# /Users/marcuspaz/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
